# %%
from pymongo import MongoClient
import pandas as pd
from json import loads
import os

data_frame = pd.read_csv(r"C:\Users\Vishal\Desktop\TourismPackage\notebooks\Travel.csv")


records = list(loads(data_frame.T.to_json()).values())

client = MongoClient(
    f'mongodb+srv://iNeuron:{os.environ["iNeuronDBPassword"]}@ineuron-ai-projects.7eh1w4s.mongodb.net/?retryWrites=true&w=majority'
)

# database_name = client['iNeuron']

# collection = database_name['tourism']

# collection.insert_many(records)

# %%
database_name = client["ineuron"]
database_name
# Out:
# Database(MongoClient(host=['ac-jjjbrnl-shard-00-01.7eh1w4s.mongodb.net:27017', 'ac-jjjbrnl-shard-00-00.7eh1w4s.mongodb.net:27017', 'ac-jjjbrnl-shard-00-02.7eh1w4s.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-okvkrd-shard-0', tls=True), 'ineuron')

# %%
collection = database_name["tourism"]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['ac-jjjbrnl-shard-00-01.7eh1w4s.mongodb.net:27017', 'ac-jjjbrnl-shard-00-00.7eh1w4s.mongodb.net:27017', 'ac-jjjbrnl-shard-00-02.7eh1w4s.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-okvkrd-shard-0', tls=True), 'ineuron'), 'tourism')

# %%
# collection.insert_many(records)

# %%
df = pd.DataFrame(list[collection.find()])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21920\755568296.py in <module>
# ----> 1 df = pd.DataFrame(list[collection.find()])
#       2 df
#
# TypeError: 'type' object is not subscriptable

# %%
# Out:
# {'_id': ObjectId('6334474a902bd253f02aa8af'), 'CustomerID': 200000, 'ProdTaken': 1, 'Age': 41.0, 'TypeofContact': 'Self Enquiry', 'CityTier': 3, 'DurationOfPitch': 6.0, 'Occupation': 'Salaried', 'Gender': 'Female', 'NumberOfPersonVisiting': 3, 'NumberOfFollowups': 3.0, 'ProductPitched': 'Deluxe', 'PreferredPropertyStar': 3.0, 'MaritalStatus': 'Single', 'NumberOfTrips': 1.0, 'Passport': 1, 'PitchSatisfactionScore': 2, 'OwnCar': 1, 'NumberOfChildrenVisiting': 0.0, 'Designation': 'Manager', 'MonthlyIncome': 20993.0}
# ...
